# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import date, datetime, timedelta
# web scrapping
import bs4 as bs
import requests
import lxml
from functools import reduce
# matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
from ipysigma import Sigma
from pyvis.network import Network
import requests
from bs4 import BeautifulSoup
from io import StringIO
from dbconnection import MySQLDatabase
from utils import getSymbols, getData, get_last_date, get_marketid_simbols
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module="pandas")
sns.set_theme()

# %%
db = MySQLDatabase("financialmarkets")

# %% [markdown]
# ## Se obtienen simbolos de wikipedia

# %%
tab_info = getSymbols('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
tab_info
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# 2                           Health Care Equipment  North Chicago, Illinois
# 3                                   Biotechnology  North Chicago, Illinois
# 4                  IT Consulting & Other Services          Dublin, Ireland
# ..                                            ...                      ...
# 498  Industrial Machinery & Supplies & Components   White Plains, New York
# 499                                   Restaurants     Louisville, Kentucky
# 500            Electronic Equipment & Instruments   Lincolnshire, Illinois
# 501                         Health Care Equipment          Warsaw, Indiana
# 502                               Pharmaceuticals   Parsippany, New Jersey
#
#      Date added      CIK      Founded
# 0    1957-03-04    66740         1902
# 1    2017-07-26    91142         1916
# 2    1957-03-04     1800         1888
# 3    2012-12-31  1551152  2013 (1888)
# 4    2011-07-06  1467373         1989
# ..          ...      ...          ...
# 498  2011-11-01  1524472         2011
# 499  1997-10-06  1041061         1997
# 500  2019-12-23   877212         1969
# 501  2001-08-07  1136869         1927
# 502  2013-06-21  1555280         1952
#
# [503 rows x 8 columns]

# %%
date = datetime.today()
today = date.strftime('%Y-%m-%d')
today

# %%
symbols = tab_info['Symbol'].to_list()

# %%
print(yf.__version__)

# %%
# Example tickers (use full S&P 500 list if you want)
# tickers = stocks2
# selección de muestra
stocks2= symbols
start_date = '2020-01-01'
today = datetime.today() - timedelta(days=0)
end_date = today.strftime("%Y-%m-%d")
# data frame precios de cierre
data = getData(stocks2, start_date, end_date)
data.head()

# %%
# ---------------------------
# 3️⃣ Insertar/actualizar mercados
# ---------------------------
markets = pd.DataFrame({
    'market_name': ['S&P 500'],
    'country': ['USA'],
    'currency': ['USD']
})
markets

# %%
db.insert_to_db(markets, tabla="markets", batch_size=5000)

# %%
# Obtener market_id
market_id = db.execute_query("SELECT * FROM markets")
market_id

# %% [markdown]
# **Tabla 2: sectores**

# %%
sectors_unique = tab_info[['GICS Sector', 'GICS Sub-Industry']].drop_duplicates()
sectors_unique.columns = ['sector_name', 'sub_industry']

# %%
sectors_unique

# %%
db.insert_to_db(sectors_unique, tabla="sectors", batch_size=5000)

# %%
sector_map = db.execute_query("SELECT * FROM sectors")

# %%
sector_map

# %% [markdown]
# **Empresas**

# %%
# Agregar sector_id
df = tab_info.merge(sector_map, left_on=['GICS Sector','GICS Sub-Industry'], right_on=['sector_name','sub_industry'], how='left')

companies = df[['Symbol','Security','sector_id','Headquarters Location','CIK','Founded']]
companies.columns = ['symbol','name','sector_id','headquarters','cik','founded']
companies['founded'] = [str(x)[:4] for x in companies['founded']]
companies = companies.reset_index(drop=True)

# %%
companies

# %%
db.insert_to_db(companies, tabla="companies", batch_size=100)

# %%
data = data.dropna(axis=1)

# %%
# Obtener mapping symbol -> company_id
company_map = db.execute_query("SELECT company_id, symbol FROM companies")
company_map

# %% [markdown]
# **Empresas**

# %%
company_map.columns

# %%
market_companies_df = tab_info[['Symbol','Date added']].merge(company_map, left_on='Symbol', right_on='symbol', how='left')
market_companies_df['market_id'] = [market_id['market_id'][0] for x in market_companies_df['Symbol']]
market_companies_df = market_companies_df[['market_id','company_id','Date added']]
market_companies_df.columns = ['market_id','company_id','date_added']
market_companies_df

# %%
db.insert_to_db(market_companies_df, tabla="market_companies", batch_size=100)

# %% [markdown]
# ## Ingresar precios

# %%
# mercado
mercados = ['S&P 500']
# dataframe con compañias y id
company_map = db.execute_query("SELECT company_id, symbol FROM companies")
for mercado in mercados: 
    market_id, list_symbols = get_marketid_simbols(mercado)
    
    for symbol in list_symbols:
        start_date = get_last_date(symbol)
        print(f"Descargando {symbol} desde {start_date}")
        
        data = yf.download(symbol, start=start_date, progress=False, auto_adjust=False)
        
        if data.empty:
            continue
        
        data = data.reset_index()
        data.columns = [x for x,y in data.columns]
        #data['Symbol'] = [symbol for x in data['Symbol']]
        data = data.rename(columns={
            'Date': 'date',
            'Open': 'open_price',
            'Close': 'close_price',
            'High': 'high_price',
            'Low': 'low_price',
            'Volume': 'volume'
        })
        
        data['date'] = pd.to_datetime(data['date'], "%Y-%m-%d")
        # Interpolación lineal
    
        data = data.set_index('date').asfreq('D')
        #print(data.reset_index())
        
        data[['open_price','close_price','high_price','low_price','volume']] = \
            data[['open_price','close_price','high_price','low_price','volume']].interpolate(method='linear')
        data.loc[:,'symbol'] = [symbol for x in data['open_price']]
        data = data.reset_index()
        data = data.merge(company_map, left_on='symbol', right_on='symbol', how='left')
        data.loc[:,'market_id'] = [market_id for x in data['open_price']]
        # limpieza
        data_final = data[['company_id','market_id','date','open_price','close_price',
                            'high_price','low_price','volume']]
        data_final.loc[:,'company_id'] = data_final['company_id'].astype(int)
        data_final.loc[:,'market_id'] = data_final['market_id'].astype(int)
        data_final.loc[:,'date'] = pd.to_datetime(data_final['date'])
        data_final.loc[:,'open_price'] = data_final['open_price'].astype(float)
        data_final.loc[:,'close_price'] = data_final['close_price'].astype(float)
        data_final.loc[:,'high_price'] = data_final['high_price'].astype(float)
        data_final.loc[:,'low_price'] = data_final['low_price'].astype(float)
        data_final.loc[:,'volume'] = data_final['volume'].astype(int)
        # inserta datos a base 
        db.insert_to_db(data_final, tabla="stock_prices", batch_size=500)
# Out:
# Descargando MMM desde 2025-10-18
# Descargando AOS desde 2025-10-18
# Descargando ABT desde 2025-10-18
# Descargando ABBV desde 2025-10-18
# Descargando ACN desde 2025-10-18
# Descargando ADBE desde 2025-10-18
# Descargando AMD desde 2025-10-18
# Descargando AES desde 2025-10-18
# Descargando AFL desde 2025-10-18
# Descargando A desde 2025-10-18
# Descargando APD desde 2025-10-18
# Descargando ABNB desde 2025-10-18
# Descargando AKAM desde 2025-10-18
# Descargando ALB desde 2025-10-18
# Descargando ARE desde 2025-10-18
# Descargando ALGN desde 2025-10-18
# Descargando ALLE desde 2025-10-18
# Descargando LNT desde 2025-10-18
# Descargando ALL desde 2025-10-18
# Descargando GOOGL desde 2025-10-18
# Descargando GOOG desde 2025-10-18
# Descargando MO desde 2025-10-18
# Descargando AMZN desde 2025-10-18
# Descargando AMCR desde 2025-10-18
# Descargando AEE desde 2025-10-18
# Descargando AEP desde 2025-10-18
# Descargando AXP desde 2025-10-18
# Descargando AIG desde 2025-10-18
# Descargando AMT desde 2025-10-18
# Descargando AWK desde 2025-10-18
# Descargando AMP desde 2025-10-18
# Descargando AME desde 2025-10-18
# Descargando AMGN desde 2025-10-18
# Descargando APH desde 2025-10-18
# Descargando ADI desde 2025-10-18
# Descargando AON desde 2025-10-18
# Descargando APA desde 2025-10-18
# Descargando APO desde 2025-10-18
# Descargando AAPL desde 2025-10-18
# Descargando AMAT desde 2025-10-18
# Descargando APP desde 2025-10-18
# Descargando APTV desde 2025-10-18
# Descargando ACGL desde 2025-10-18
# Descargando ADM desde 2025-10-18
# Descargando ANET desde 2025-10-18
# Descargando AJG desde 2025-10-18
# Descargando AIZ desde 2025-10-18
# Descargando T desde 2025-10-18
# Descargando ATO desde 2025-10-18
# Descargando ADSK desde 2025-10-18
# Descargando ADP desde 2025-10-18
# Descargando AZO desde 2025-10-18
# Descargando AVB desde 2025-10-18
# Descargando AVY desde 2025-10-18
# Descargando AXON desde 2025-10-18
# Descargando BKR desde 2025-10-18
# Descargando BALL desde 2025-10-18
# Descargando BAC desde 2025-10-18
# Descargando BAX desde 2025-10-18
# Descargando BDX desde 2025-10-18
# Descargando BRK.B desde 2000-01-01
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')
# Datos vacios, {symbol} actualizado hasta última fecha disponible
# Descargando BBY desde 2025-10-18
# Descargando TECH desde 2025-10-18
# Descargando BIIB desde 2025-10-18
# Descargando BLK desde 2025-10-18
# Descargando BX desde 2025-10-18
# Descargando XYZ desde 2025-10-18
# Descargando BK desde 2025-10-18
# Descargando BA desde 2025-10-18
# Descargando BKNG desde 2025-10-18
# Descargando BSX desde 2025-10-18
# Descargando BMY desde 2025-10-18
# Descargando AVGO desde 2025-10-18
# Descargando BR desde 2025-10-18
# Descargando BRO desde 2025-10-18
# 1 Failed download:
# ['BF.B']: YFPricesMissingError('possibly delisted; no price data found  (1d 2000-01-01 -> 2025-10-19)')
# Descargando BF.B desde 2000-01-01
# Datos vacios, {symbol} actualizado hasta última fecha disponible
# Descargando BLDR desde 2025-10-18
# Descargando BG desde 2025-10-18
# Descargando BXP desde 2025-10-18
# Descargando CHRW desde 2025-10-18
# Descargando CDNS desde 2025-10-18
# Descargando CPT desde 2025-10-18
# Descargando CPB desde 2025-10-18
# Descargando COF desde 2025-10-18
# Descargando CAH desde 2025-10-18
# Descargando KMX desde 2025-10-18
# Descargando CCL desde 2025-10-18
# Descargando CARR desde 2025-10-18
# Descargando CAT desde 2025-10-18
# Descargando CBOE desde 2025-10-18
# Descargando CBRE desde 2025-10-18
# Descargando CDW desde 2025-10-18
# Descargando COR desde 2025-10-18
# Descargando CNC desde 2025-10-18
# Descargando CNP desde 2025-10-18
# Descargando CF desde 2025-10-18
# Descargando CRL desde 2025-10-18
# Descargando SCHW desde 2025-10-18
# Descargando CHTR desde 2025-10-18
# Descargando CVX desde 2025-10-18
# Descargando CMG desde 2025-10-18
# Descargando CB desde 2025-10-18
# Descargando CHD desde 2025-10-18
# Descargando CI desde 2025-10-18
# Descargando CINF desde 2025-10-18
# Descargando CTAS desde 2025-10-18
# Descargando CSCO desde 2025-10-18
# Descargando C desde 2025-10-18
# Descargando CFG desde 2025-10-18
# Descargando CLX desde 2025-10-18
# Descargando CME desde 2025-10-18
# Descargando CMS desde 2025-10-18
# Descargando KO desde 2025-10-18
# Descargando CTSH desde 2025-10-18
# Descargando COIN desde 2025-10-18
# Descargando CL desde 2025-10-18
# Descargando CMCSA desde 2025-10-18
# Descargando CAG desde 2025-10-18
# Descargando LEN desde 2025-10-18
# Descargando LII desde 2025-10-18
# Descargando LLY desde 2025-10-18
# Descargando LIN desde 2025-10-18
# Descargando LYV desde 2025-10-18
# Descargando LKQ desde 2025-10-18
# Descargando LMT desde 2025-10-18
# Descargando L desde 2025-10-18
# Descargando LOW desde 2025-10-18
# Descargando LULU desde 2025-10-18
# Descargando LYB desde 2025-10-18
# Descargando MTB desde 2025-10-18
# Descargando MPC desde 2025-10-18
# Descargando MAR desde 2025-10-18
# Descargando MMC desde 2025-10-18
# Descargando MLM desde 2025-10-18
# Descargando MAS desde 2025-10-18
# Descargando MA desde 2025-10-18
# Descargando MTCH desde 2025-10-18
# Descargando MKC desde 2025-10-18
# Descargando MCD desde 2025-10-18
# Descargando MCK desde 2025-10-18
# Descargando MDT desde 2025-10-18
# Descargando MRK desde 2025-10-18
# Descargando META desde 2025-10-18
# Descargando MET desde 2025-10-18
# Descargando MTD desde 2025-10-18
# Descargando MGM desde 2025-10-18
# Descargando MCHP desde 2025-10-18
# Descargando MU desde 2025-10-18
# Descargando MSFT desde 2025-10-18
# Descargando MAA desde 2025-10-18
# Descargando MRNA desde 2025-10-18
# Descargando MHK desde 2025-10-18
# Descargando MOH desde 2025-10-18
# Descargando TAP desde 2025-10-18
# Descargando MDLZ desde 2025-10-18
# Descargando MPWR desde 2025-10-18
# Descargando MNST desde 2025-10-18
# Descargando MCO desde 2025-10-18
# Descargando MS desde 2025-10-18
# Descargando MOS desde 2025-10-18
# Descargando MSI desde 2025-10-18
# Descargando MSCI desde 2025-10-18
# Descargando NDAQ desde 2025-10-18
# Descargando NTAP desde 2025-10-18
# Descargando NFLX desde 2025-10-18
# Descargando NEM desde 2025-10-18
# Descargando NWSA desde 2025-10-18
# Descargando NWS desde 2025-10-18
# Descargando NEE desde 2025-10-18
# Descargando NKE desde 2025-10-18
# Descargando NI desde 2025-10-18
# Descargando NDSN desde 2025-10-18
# Descargando NSC desde 2025-10-18
# Descargando NTRS desde 2025-10-18
# Descargando NOC desde 2025-10-18
# Descargando NCLH desde 2025-10-18
# Descargando NRG desde 2025-10-18
# Descargando NUE desde 2025-10-18
# Descargando NVDA desde 2025-10-18
# Descargando NVR desde 2025-10-18
# Descargando NXPI desde 2025-10-18
# Descargando ORLY desde 2025-10-18
# Descargando OXY desde 2025-10-18
# Descargando ODFL desde 2025-10-18
# Descargando OMC desde 2025-10-18
# Descargando ON desde 2025-10-18
# Descargando OKE desde 2025-10-18
# Descargando ORCL desde 2025-10-18
# Descargando OTIS desde 2025-10-18
# Descargando PCAR desde 2025-10-18
# Descargando PKG desde 2025-10-18
# Descargando PLTR desde 2025-10-18
# Descargando PANW desde 2025-10-18
# Descargando PSKY desde 2025-10-18
# Descargando PH desde 2025-10-18
# Descargando PAYX desde 2025-10-18
# Descargando PAYC desde 2025-10-18
# Descargando PYPL desde 2025-10-18
# Descargando PNR desde 2025-10-18
# Descargando PEP desde 2025-10-18
# Descargando PFE desde 2025-10-18
# Descargando TRMB desde 2025-10-18
# Descargando TFC desde 2025-10-18
# Descargando TYL desde 2025-10-18
# Descargando TSN desde 2025-10-18
# Descargando USB desde 2025-10-18
# Descargando UBER desde 2025-10-18
# Descargando UDR desde 2025-10-18
# Descargando ULTA desde 2025-10-18
# Descargando UNP desde 2025-10-18
# Descargando UAL desde 2025-10-18
# Descargando UPS desde 2025-10-18
# Descargando URI desde 2025-10-18
# Descargando UNH desde 2025-10-18
# Descargando UHS desde 2025-10-18
# Descargando VLO desde 2025-10-18
# Descargando VTR desde 2025-10-18
# Descargando VLTO desde 2025-10-18
# Descargando VRSN desde 2025-10-18
# Descargando VRSK desde 2025-10-18
# Descargando VZ desde 2025-10-18
# Descargando VRTX desde 2025-10-18
# Descargando VTRS desde 2025-10-18
# Descargando VICI desde 2025-10-18
# Descargando V desde 2025-10-18
# Descargando VST desde 2025-10-18
# Descargando VMC desde 2025-10-18
# Descargando WRB desde 2025-10-18
# Descargando GWW desde 2025-10-18
# Descargando WAB desde 2025-10-18
# Descargando WMT desde 2025-10-18
# Descargando DIS desde 2025-10-18
# Descargando WBD desde 2025-10-18
# Descargando WM desde 2025-10-18
# Descargando WAT desde 2025-10-18
# Descargando WEC desde 2025-10-18
# Descargando WFC desde 2025-10-18
# Descargando WELL desde 2025-10-18
# Descargando WST desde 2025-10-18
# Descargando WDC desde 2025-10-18
# Descargando WY desde 2025-10-18
# Descargando WSM desde 2025-10-18
# Descargando WMB desde 2025-10-18
# Descargando WTW desde 2025-10-18
# Descargando WDAY desde 2025-10-18
# Descargando WYNN desde 2025-10-18
# Descargando XEL desde 2025-10-18
# Descargando XYL desde 2025-10-18
# Descargando YUM desde 2025-10-18
# Descargando ZBRA desde 2025-10-18
# Descargando ZBH desde 2025-10-18
# Descargando ZTS desde 2025-10-18

# %%
# Example tickers (use full S&P 500 list if you want)
#tickers = stocks2

# Download adjusted close prices
#prices = yf.download(tickers, start='2020-01-01', end='2025-01-01')['Close']

#prices = prices.fillna(method='bfill')
# Calculate daily returns
returns = data.pct_change().dropna()

# Compute correlation matrix
correlation_matrix = returns.corr()

# Set correlation threshold
threshold = 0.7

# Create graph
G = nx.Graph()

# Add nodes
for ticker in correlation_matrix.columns:
    G.add_node(ticker)

# Add edges with correlation above threshold
for i, stock1 in enumerate(correlation_matrix.columns):
    for j, stock2 in enumerate(correlation_matrix.columns):
        if i < j:
            corr = correlation_matrix.iloc[i, j]
            if abs(corr) >= threshold:
                G.add_edge(stock1, stock2, weight=corr)

# Display with ipysigma
#Sigma(G)
# Initialize pyvis network
#net = Network(notebook=True)
#net.from_nx(G)

# Save and show the graph
#net.show("graph.html")
Sigma.write_html(
    G,
    './dataset.html',
    fullscreen=True,
    node_metrics=['louvain'],
    node_color='louvain',
    node_size_range=(3, 15),
    max_categorical_colors=30,
    default_edge_type='curve',
    node_border_color_from='node',
    default_node_label_size=14,
    node_size=G.degree
)

# %%
from IPython.display import IFrame
IFrame('graph.html', width=800, height=600)
